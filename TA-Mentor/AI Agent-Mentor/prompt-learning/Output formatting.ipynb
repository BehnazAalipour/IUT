# %%
import os
from dotenv import load_dotenv
from langchain_openai import OpenAI

from langchain.prompts import PromptTemplate
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
api_key= os.getenv("OPENAI_API_KEY")
llm=OpenAI(model="gpt-4o-mini")

prompt = ChatPromptTemplate.from_template(
    "Give 3 pros and 3 cons of {tool} in a markdown table with two columns."
)
print((prompt | llm | StrOutputParser()).invoke({"tool": "LangChain"}))
# Out:
#
#
# Assistant<|im_sep|>| Pros                                      | Cons                                            |
# |-------------------------------------------|------------------------------------------------|
# | 1. Simplifies the development of LLM apps | 1. May have a learning curve for beginners     |
# | 2. Supports various data sources          | 2. Performance may vary based on implementation |
# | 3. Modular architecture for flexibility    | 3. Dependency on third-party libraries         |
