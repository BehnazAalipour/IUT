# %%
import os
from dotenv import load_dotenv
from langchain_openai import OpenAI
from langchain.prompts import PromptTemplate
from langchain.schema.output_parser import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
api_key= os.getenv("OPENAI_API_KEY")

llm=OpenAI(model="gpt-4o-mini",temperature=0)

prompt = PromptTemplate.from_template(
    "You are a helpful tutor. Explain {topic} to a {audience} in exactly {n} bullet points."
)

chain = prompt | llm | StrOutputParser()
print(chain.invoke({"topic": "LangChain", "audience": "beginner", "n": 3}))
# Out:
#
#
# - LangChain is a framework designed to simplify the development of applications that use language models.
# - It provides tools and components to easily integrate language models into various applications.
# - LangChain supports multiple use cases, such as chatbots, question-answering systems, and content generation.
