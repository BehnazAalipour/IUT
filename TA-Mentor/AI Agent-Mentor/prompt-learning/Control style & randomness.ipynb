# %%
import os
from dotenv import load_dotenv
from langchain_openai import OpenAI


from langchain.prompts import PromptTemplate
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
api_key= os.getenv("OPENAI_API_KEY")
llm=OpenAI(model="gpt-4o-mini")

controlled_llm = llm.bind(temperature=0.2, top_p=0.9, max_tokens=30)
prompt = ChatPromptTemplate.from_template(
    "Summarize {text} in 2 bullets."
)
print((prompt | controlled_llm | StrOutputParser()).invoke({"text": "LangChain connects LLMs to tools and data."}))
# Out:
#
# Assistant:
# - LangChain enables the integration of large language models (LLMs) with various tools and data sources.
# - It facilitates enhanced functionality
