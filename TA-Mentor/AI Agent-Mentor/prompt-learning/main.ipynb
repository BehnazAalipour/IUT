# %%
import os
from dotenv import load_dotenv
from langchain_openai import OpenAI

# %%
load_dotenv()
# Out:
# True

# %%
api_key= os.getenv("OPENAI_API_KEY")

llm=OpenAI(model="gpt-4o-mini",temperature=0)
prompt="what is langchain?"
result=llm.invoke(prompt)
print("gpt responce:",result)
# Out:
# gpt responce: ](https://langchain.readthedocs.io/en/latest/index.html) is a framework for developing applications powered by language models. It provides a standard interface for interacting with various language models and tools, making it easier to build applications that leverage the capabilities of these models.
#
# LangChain is designed to help developers create applications that can understand and generate human-like text, perform natural language processing tasks, and integrate with other tools and services. It provides a set of components and abstractions that simplify the process of working with language models, allowing developers to focus on building their applications rather than dealing with the complexities of the underlying technology.
#
# Some key features of LangChain include:
#
# 1. **Modular Components**: LangChain provides a variety of modular components that can be easily combined to create complex applications. These components include language models, document loaders, text splitters, and more.
#
# 2. **Standardized Interfaces**: LangChain defines standardized interfaces for interacting with different language models and tools, making it easier to switch between different models or services without having to rewrite code.
#
# 3. **Integration with External Tools**: LangChain can be integrated with various external tools and services, such as databases, APIs, and other machine learning models, allowing developers to create more powerful applications.
#
# 4. **
