# %%
import os
from dotenv import load_dotenv
from langchain_openai import OpenAI


from langchain.prompts import PromptTemplate
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser

# %%
load_dotenv()
# Out:
# True

# %%
api_key= os.getenv("OPENAI_API_KEY")

llm=OpenAI(model="gpt-4o-mini",temperature=0)

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a AI professor. Keep answers compact and correct."),
    ("human",  "Explain {topic} with one code example and 3 bullets.")
])

chain = chat_prompt | llm | StrOutputParser()
print(chain.invoke({"topic": "Prompt Templates in LangChain"}))
# Out:
#
# Assistant:
#
# Prompt templates in LangChain are used to create structured prompts for language models, allowing for dynamic input and consistent formatting.
#
# - **Dynamic Input**: You can insert variables into the prompt template to customize the output based on user input.
# - **Reusability**: Templates can be reused across different parts of an application, promoting consistency.
# - **Ease of Maintenance**: Changes to the prompt structure can be made in one place, simplifying updates.
#
# **Code Example**:
# ```python
# from langchain import PromptTemplate
#
# template = PromptTemplate(
#     input_variables=["name"],
#     template="Hello, {name}! How can I assist you today?"
# )
#
# prompt = template.format(name="Alice")
# print(prompt)  # Output: Hello, Alice! How can I assist you today?
# ```
